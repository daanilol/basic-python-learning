# %% [markdown]
# # **Lógica de programação com Python**

# %%
1 + 1
# Out:
# 2

# %%
nome = 'Danilo'

# %%
idade = 28

# %%
nome
# Out:
# 'Danilo'

# %%
idade
# Out:
# 28

# %%
print(f'O nome é {nome} e a idade é {idade}')
# Out:
# O nome é Danilo e a idade é 28

# %% [markdown]
# # Criando minha primeira função

# %%
def saudacao():
  nome = input('Qual seu nome? ')
  print(f'Olá {nome}')

# %%
saudacao()
# Out:
# Qual seu nome? danilo
# Olá danilo

# %%
def nome_completo():
  primeiro_nome = input('Qual seu nome? ')
  sobrenome = input('Qual seu sobrenome? ')
  nome_inteiro = primeiro_nome + ' ' + sobrenome
  print(nome_inteiro)

# %%
nome_completo()
# Out:
# Qual seu nome? danilo
# Qual seu sobrenome? lisboa
# danilo lisboa

# %% [markdown]
# ## Parâmetros

# %%
nome = 'Rebecca'

# %%
def saudacao_com_parametro(nome_da_pessoa):
  print(f'Olá {nome_da_pessoa}')

# %%
saudacao_com_parametro(nome)
# Out:
# Olá Rebecca

# %% [markdown]
# ## Condicional

# %%
idade = 17

# %%
def verificando_maioridade(idade):
  if idade >= 18:
    print(f'Tem permissão para dirigir.')
  else:
    print(f'Não pode dirigir com apenas {idade} anos.')

# %%
verificando_maioridade(idade)
# Out:
# Não pode dirigir com apenas 17 anos.

# %%
def verifica_se_pode_dirigir_sem_parametros():
  idade = input('Qual sua idade? ')
  idade = int(idade)
  if idade >= 18:
    print(f'Com {idade} você pode dirigir.')
  else:
    print(f'Com {idade} você não pode dirigir.')

# %%
verifica_se_pode_dirigir_sem_parametros()
# Out:
# Qual sua idade? 15
# Com 15 você não pode dirigir.

# %% [markdown]
# # Convertendo tipo para inteiro

# %%
def velocidade():
  distancia = int(input('Informe a distância percorrida (em metros): '))
  tempo = float(input('Informe o tempo (sem segundos) que levou até o final do percurso: '))
  velocidade = distancia / tempo
  print(f'A velocidade percorrida é de {velocidade} m/s')

# %%
velocidade()
# Out:
# Informe a distância percorrida (em metros): 100
# Informe o tempo (sem segundos) que levou até o final do percurso: 20
# A velocidade percorrida é de 5.0 m/s

# %%
def verifica_se_pode_dirigir_sem_parametros():
  idade = input('Qual sua idade? ')
  idade = int(idade)
  if idade >= 18:
    print(f'Com {idade} você pode dirigir.')
  else:
    print(f'Com {idade} você não pode dirigir.')
verifica_se_pode_dirigir_sem_parametros()
# Out:
# Qual sua idade? 15
# Com 15 você não pode dirigir.

# %% [markdown]
# # Lista

# %%
idades = [30, 15, 22, 18]

# %%
idades
# Out:
# [30, 15, 22, 18]

# %%
type(idades)
# Out:
# list

# %%
idades[2]
# Out:
# 22

# %%
idades = [30, 15, 22, 18]
#indice   0   1   2   3

# %%
idades[0:2]
#slice
# Out:
# [30, 15]

# %%
idades[3]
# Out:
# 18

# %%
idades[-2]
# Out:
# 22

# %% [markdown]
# # Laços e Loops

# %%
idades
# Out:
# [30, 15, 22, 18]

# %%
#for fora da função

def verifica_se_pode_dirigir(idade):
  if idade >= 18:
    print(f'{idade} anos de idade TEM permissão para dirigir.' )
  else:
    print(f'{idade} anos de idade NÃO tem permissão para dirigir.')

#para cada idade na nossa lista:
  #verifica_se_pode_dirigir(idade)

for idade in idades:
  verifica_se_pode_dirigir(idade)
# Out:
# 30 anos de idade TEM permissão para dirigir.
# 15 anos de idade NÃO tem permissão para dirigir.
# 22 anos de idade TEM permissão para dirigir.
# 18 anos de idade TEM permissão para dirigir.

# %%
#for dentro da função
def verifica_se_pode_dirigir(idades):
  for idade in idades:
    print(f'{idade} anos de idade TEM permissão para dirigir.' )
  else:
    print(f'{idade} anos de idade NÃO tem permissão para dirigir.')

verifica_se_pode_dirigir(idades)
# Out:
# 30 anos de idade TEM permissão para dirigir.
# 15 anos de idade TEM permissão para dirigir.
# 22 anos de idade TEM permissão para dirigir.
# 18 anos de idade TEM permissão para dirigir.
# 18 anos de idade NÃO tem permissão para dirigir.

# %% [markdown]
# # Boleano

# %%
idade = 18
idade >= 18
# Out:
# True

# %%
idade = 15
idade >= 18
# Out:
# False

# %%
permissoes = []
idades = [20, 14, 40]

def verifica_se_pode_dirigir(idades, permissoes):
  for idade in idades:
    if idade >= 18:
      permissoes.append(True)
    else: 
      permissoes.append(False)

verifica_se_pode_dirigir(idades, permissoes)

# %%
permissoes
# Out:
# [True, False, True]

# %%
for permissao in permissoes:
  if permissao == True:
    print('Tem permissão para dirigir.')
  else:
    print('Não tem permissão para dirigir.')
# Out:
# Tem permissão para dirigir.
# Não tem permissão para dirigir.
# Tem permissão para dirigir.

# %% [markdown]
# # Tipos em uma lista

# %%
lista = ['Guilherme', 28, True, '18']

for item in lista:
  print(f'O item {item} é do tipo: {type(item)}')
# Out:
# O item Guilherme é do tipo: <class 'str'>
# O item 28 é do tipo: <class 'int'>
# O item True é do tipo: <class 'bool'>
# O item 18 é do tipo: <class 'str'>

# %% [markdown]
# # Import

# %%
from random import randrange, seed

# %%
seed(11)

# %%
randrange(0, 11)
# Out:
# 7

# %%
notas_matematica = []

for notas in range(8):
  notas_matematica.append(randrange(0, 11))

notas_matematica
# Out:
# [8, 7, 7, 8, 9, 3, 2, 8]

# %%
len(notas_matematica)
# Out:
# 8

# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt

# %%
x = list(range(1, 9))
x
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
y = notas_matematica
y
# Out:
# [8, 7, 7, 8, 9, 3, 2, 8]

# %%
plt.plot(x, y, marker= 'o')
plt.title('Notas de matemática')
plt.xlabel('Provas')
plt.ylabel('Notas')
plt.show()

# %%
notas_matematica
# Out:
# [8, 7, 7, 8, 9, 3, 2, 8]
