# %% [markdown]
# # Calculo com slice em arrays

# %%
import numpy as np

peso = np.array([96, 70, 54, 80])
altura = np.array([1.93, 1.60, 1.90, 1.70])

dados = np.array([[96, 70, 54, 80], [1.93, 1.60, 1.90, 1.70]])

# %%
dados
# Out:
# array([[96.  , 70.  , 54.  , 80.  ],
#        [ 1.93,  1.6 ,  1.9 ,  1.7 ]])

# %%
dados[:, :5][0] / (dados[:, :5][1] ** 2)
# Out:
# array([25.77250396, 27.34375   , 14.95844875, 27.6816609 ])

# %%
dados[:, 2][0]
# Out:
# 54.0

# %%
dados_1 = np.array([['Roberto', 'casado', 'masculino'], ['Sheila', 'solteiro', 'feminino'], ['Bruno', 'solteiro', 'masculino'], ['Rita', 'casado', 'feminino']])
dados_1
# Out:
# array([['Roberto', 'casado', 'masculino'],
#        ['Sheila', 'solteiro', 'feminino'],
#        ['Bruno', 'solteiro', 'masculino'],
#        ['Rita', 'casado', 'feminino']], dtype='<U9')

# %%
#booleano mostra local em que aparecem os masculinos
a = dados_1[::2, 2] == 'masculino'

# %%
a
# Out:
# array([ True,  True])

# %%
a = dados_1[:, 2] == 'masculino'

# %%
a
# Out:
# array([ True, False,  True, False])

# %%
#[:(todas as linhas):(de 2 em 2) :(até o indice 1), ]
dados_1[::2, :2]
# Out:
# array([['Roberto', 'casado'],
#        ['Bruno', 'solteiro']], dtype='<U9')

# %% [markdown]
# # FIM
